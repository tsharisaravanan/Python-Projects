# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing dataset
data=pd.read_csv('Chennai_Zomato_Data_updated.csv')

# %%
# know about the columns
data.columns
# Out:
# Index(['Unnamed: 0', 'Zomato URL', 'Name of Restaurant', 'Address', 'Location',
#        'Cuisine', 'Top Dishes', 'Price for 2', 'Ratings', 'No of Votes'],
#       dtype='object')

# %%
#know about categorical features in the the data frame
data.describe(include=np.object)
# so Zomato URL	Name of Restaurant	Address	Location	Cuisine	Top Dishes	Ratings	No of Votes are the categorical features in the data frame
# Out:
#                                                Zomato URL  Name of Restaurant  \
# count                                                8505                8505
# unique                                               8334                7890
# top     https://www.zomato.com/chennai/tastea-cafee-na...  Sri Krishna Bhavan
# freq                                                    2                  13
#
#                Address Location       Cuisine Top Dishes  Ratings No of Votes
# count             8505     8505          8505       8505     8505        8505
# unique            7780      271          2168       1492       30         703
# top      Delivery Only    Porur  South Indian    Invalid  invalid     invalid
# freq                90      293           752       6871     3034        3037

# %%
# know about the numerical features in the data frame
data.describe(exclude=np.object)
# fromt this Unnamed: 0	Price for 2 are the numerical features in the data frame
# Out:
#         Unnamed: 0  Price for 2
# count  8505.000000  8505.000000
# mean   4252.000000   419.582598
# std    2455.326353   412.945335
# min       0.000000    40.000000
# 25%    2126.000000   200.000000
# 50%    4252.000000   300.000000
# 75%    6378.000000   450.000000
# max    8504.000000  5500.000000

# %%
# to see hwo many null values are there
data.isnull().sum()
# Out:
# Unnamed: 0            0
# Zomato URL            0
# Name of Restaurant    0
# Address               0
# Location              0
# Cuisine               0
# Top Dishes            0
# Price for 2           0
# Ratings               0
# No of Votes           0
# dtype: int64

# %%
# even though Ratings and No of votes are shown as the categorical features, they are basically numerical features.
# so we have to change the "invalid" value in to some other value
# if we are not change 'invalid' valid there will be trouble in data analysis so we are going to change those into np.NaN
def invalid(feature_name):
    data[feature_name]=data[feature_name].apply(lambda x:np.NaN if x=='invalid' else float(x))

# %%
invalid_features=['Ratings','No of Votes']
for i in invalid_features:
    invalid(i)

# %%
# to see how many features has null values
data.isnull().sum()
# from this only Ratings and No of Votes has null values since we changed the 'invalid' into null values
# Out:
# Unnamed: 0               0
# Zomato URL               0
# Name of Restaurant       0
# Address                  0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Ratings               3034
# No of Votes           3037
# dtype: int64

# %%
# from the description of categorical features 'Zomato URL', 'Name of Restaurant', 'Address' has nearly all the values as unique values.
# since this data set is not a regression of classification problem we can't relate these features (mostly unique values).
# Location feature has 271 unqiue values so each location has 1 or more than 1 restaurants.
# we are going to see which location has highest and which location has lowest number of restaurants in their respective location.
loc=data[['Location','Name of Restaurant']].groupby(['Location']).count()
loc=loc.reset_index()
loc.sort_values(by='Name of Restaurant',ascending=False)
# from this 'Porur' has most number of restaurant in Zomato and 60 other location has only one restaurant in Zomato
# Out:
#                                        Location  Name of Restaurant
# 190                                       Porur                 293
# 261                                   Velachery                 255
# 222                                    T. Nagar                 229
# 15                              Anna Nagar East                 227
# 10                                     Ambattur                 212
# 165                                Nungambakkam                 206
# 186                                   Perungudi                 197
# 185                                    Perambur                 189
# 228                                    Tambaram                 167
# 16                              Anna Nagar West                 164
# 200                                   Ramapuram                 160
# 150                                  Medavakkam                 152
# 251                                Thuraipakkam                 147
# 129                                    Kolathur                 145
# 211                                    Selaiyur                 143
# 142                                  Madipakkam                 141
# 55                                     GST Road                 140
# 215                              Sholinganallur                 136
# 126                                     Kilpauk                 132
# 179                                  Pallavaram                 132
# 153                                   Mogappair                 121
# 31                                    Chromepet                 121
# 4                                         Adyar                 118
# 155                                    Mylapore                 116
# 191                                     Potheri                 106
# 249                               Thiruvanmiyur                 106
# 189                                  Poonamalle                 103
# 20                                  Ashok Nagar                 102
# 128                                 Kodambakkam                 102
# 43                                       Egmore                  95
# ..                                          ...                 ...
# 79                  Hotel Blue Nile, Pallavaram                   1
# 219     Spectrum The Grand Venus Mall, Perambur                   1
# 139             Liberty Park Hotel, Kodambakkam                   1
# 41                      Eat And Pack, Ambattur                    1
# 172                OMR Food Street,Thuraipakkam                   1
# 78                  Hotel Blue Diamond, Kilpauk                   1
# 77                    Hotel Bhimaas, Vadapalani                   1
# 223                         TNHB Complex, Adyar                   1
# 37     Days Hotel, Old Mahabalipuram Road (OMR)                   1
# 224                  TNHB Complex, Besant Nagar                   1
# 119         Jade Resorts, East Coast Road (ECR)                   1
# 2                   Abu Sarovar Portico, Egmore                   1
# 113    IBIS Hotel, Old Mahabalipuram Road (OMR)                   1
# 89       Hotel Maurya International, Vadapalani                   1
# 96                     Hotel Poigai, Arumbakkam                   1
# 112                           IBIS Chennai, OMR                   1
# 110                      Hotel Victoria, Egmore                   1
# 53                 GLM Meridian Hotel, T. Nagar                   1
# 74                     Hotel Abu Palace, Egmore                   1
# 73                   Hotel Aadithya, Vadapalani                   1
# 246            The Vijay Park Hotel, Arumbakkam                   1
# 106             Hotel Sky Park, Anna Nagar West                   1
# 91                   Hotel Mount Heera, Alandur                   1
# 92                Hotel NRS Sakithyan, T. Nagar                   1
# 95                    Hotel Peninsula, T. Nagar                   1
# 102                 Hotel Royal Regency, Vepery                   1
# 64                            Grande Bay Resort                   1
# 238                    The Pride Hotel, Kilpauk                   1
# 65   Green Coconut Resort, Kanchipuram District                   1
# 217               Southern Residency Hotel, OMR                   1
#
# [271 rows x 2 columns]

# %%
# its better understanding if we done this by visualization.
plt.subplots(figsize=[10,50])
sns.countplot(y='Location',data=data)
plt.xticks(rotation=90)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text xticklabel objects>)

# %%
# there are 2168 unique orders in cuisine feature so we are going to see some top ordered cuisines
cs=data[['Cuisine','Unnamed: 0']].groupby('Cuisine').count()
cs=cs.reset_index()
cs=cs[cs['Unnamed: 0']>np.median(cs['Unnamed: 0'].unique())].sort_values(by='Unnamed: 0',ascending=False)
# from this we can see that South indian cuisine has ordered by the most of the customers
# Out:
#                                   Cuisine  Unnamed: 0
# 1886                         South Indian         752
# 962                             Fast Food         300
# 295                               Biryani         222
# 1458                North Indian, Chinese         206
# 1932                South Indian, Chinese         202
# 972                  Fast Food, Beverages         170
# 1407                         North Indian         166
# 163                                Bakery         158
# 637                               Chinese         142
# 231                             Beverages         131
# 319                      Biryani, Chinese         121
# 2022  South Indian, North Indian, Chinese         115
# 246                  Beverages, Fast Food          90
# 2009           South Indian, North Indian          88
# 728                 Chinese, North Indian          85
# 2086                          Street Food          76
# 1111                          Finger Food          73
# 172                      Bakery, Desserts          72
# 179                     Bakery, Fast Food          70
# 1693  North Indian, South Indian, Chinese          62
# 787                 Chinese, South Indian          61
# 432                 Biryani, South Indian          58
# 923                              Desserts          55
# 1677           North Indian, South Indian          46
# 1964  South Indian, Chinese, North Indian          44
# 1476       North Indian, Chinese, Biryani          44
# 353                    Biryani, Fast Food          42
# 385                 Biryani, North Indian          41
# 1160                  Ice Cream, Desserts          40
# 266                     Beverages, Juices          40
# 1225                               Juices          39
# 393        Biryani, North Indian, Chinese          37
# 2098               Street Food, Fast Food          37
# 1755                     Pizza, Fast Food          36
# 494                                  Cafe          34

# %%
# like location feature it is better to plot in chart
plt.subplots(figsize=[5,10])
plt.barh(width=cs['Unnamed: 0'],y=cs['Cuisine'])
plt.xticks(rotation=90)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700., 800.]),
#  <a list of 9 Text xticklabel objects>)

# %%
# there are 1492 unqiue values in Top Dishes features.
# most of them are ordered 1 or 2 times so we are going to take the Dish type which ordered more than 2 times.
td=data[['Top Dishes','Unnamed: 0']].groupby('Top Dishes').count()
td=td.reset_index()
td=td[td['Unnamed: 0']>2].sort_values(by='Unnamed: 0',ascending=False)
# we can't change 'invalid' in this feature. because it can be any type of Dish. so we are going to change it as others
td['Top Dishes']=td['Top Dishes'].apply(lambda x:'others' if x=='Invalid' else x)
# from this we can see most of the people ordered biryani
# Out:
#                  Top Dishes  Unnamed: 0
# 724                  others        6871
# 64                  Biryani          20
# 284         Chicken Biryani           9
# 472                  Coffee           7
# 50                     Beer           7
# 418               Cocktails           7
# 939                 Paratha           6
# 306           Chicken Grill           6
# 1286               Shawarma           5
# 930   Panneer Butter Masala           5
# 1376                  Thali           4
# 229              Buttermilk           4
# 419          Cocktails,Beer           3
# 516                 Cupcake           3
# 562                  Faluda           3
# 648          Friendly Staff           3
# 215          Butter Chicken           3
# 159                 Burgers           3
# 1071                  Pizza           3
# 1186                   Roti           3
# 74    Biryani,Chicken Grill           3
# 1341       Tandoori Chicken           3
# 41             Beef Biryani           3

# %%
#plt.subplot(figsize=[5,10])
plt.barh(width=td['Unnamed: 0'][1:],y=td['Top Dishes'][1:])
# Out:
# <BarContainer object of 22 artists>

# %%
# price for 2 feature has 61 unique values so most of the food items has same rate.
pf2=data[['Price for 2','Unnamed: 0']].groupby('Price for 2').count()
pf2=pf2.reset_index()
pf2.sort_values(by='Unnamed: 0',ascending=False)
# from this 300INR has most ordered food items
# Out:
#     Price for 2  Unnamed: 0
# 9         300.0        1461
# 7         200.0        1406
# 8         250.0         921
# 13        400.0         919
# 15        500.0         654
# 5         150.0         618
# 10        350.0         536
# 3         100.0         312
# 17        600.0         287
# 14        450.0         284
# 19        700.0         139
# 21        800.0         138
# 16        550.0         120
# 25       1000.0         111
# 31       1500.0          88
# 27       1200.0          61
# 18        650.0          55
# 23        900.0          51
# 44       2500.0          37
# 39       2000.0          30
# 26       1100.0          27
# 48       3000.0          27
# 30       1400.0          25
# 20        750.0          24
# 33       1600.0          22
# 28       1300.0          20
# 22        850.0          20
# 36       1800.0          16
# 35       1700.0          15
# 41       2200.0           6
# ..          ...         ...
# 42       2300.0           5
# 24        950.0           5
# 47       2800.0           5
# 53       3500.0           5
# 46       2700.0           4
# 55       4000.0           4
# 1          50.0           4
# 45       2600.0           3
# 38       1900.0           3
# 43       2400.0           3
# 57       4500.0           2
# 50       3200.0           2
# 59       5000.0           2
# 60       5500.0           2
# 34       1650.0           2
# 32       1550.0           2
# 29       1350.0           2
# 4         120.0           2
# 37       1850.0           1
# 49       3100.0           1
# 12        390.0           1
# 51       3300.0           1
# 52       3400.0           1
# 11        360.0           1
# 54       3800.0           1
# 6         160.0           1
# 56       4200.0           1
# 58       4800.0           1
# 2          60.0           1
# 0          40.0           1
#
# [61 rows x 2 columns]

# %%
f,ax=plt.subplots(figsize=[10,15])
sns.countplot(y='Price for 2',data=data)

# %%
# then we can know which rating as given by customers
data[['Ratings','Unnamed: 0']].groupby('Ratings').count()
# Out:
#          Unnamed: 0
# Ratings
# 2.1               2
# 2.2               3
# 2.3               4
# 2.4              11
# 2.5              19
# 2.6              34
# 2.7              56
# 2.8             121
# 2.9             222
# 3.0             363
# 3.1             489
# 3.2             526
# 3.3             553
# 3.4             499
# 3.5             444
# 3.6             432
# 3.7             369
# 3.8             337
# 3.9             270
# 4.0             197
# 4.1             164
# 4.2             132
# 4.3              84
# 4.4              60
# 4.5              39
# 4.6              22
# 4.7              13
# 4.8               4
# 4.9               2

# %%
plt.subplots(figsize=[5,10])
sns.countplot(y='Ratings',data=data)

# %%
# from the description we knew the 'Ratings' and 'No of Votes' has relations. so multiple ratings has more votes
rating_votes=data[['Ratings','No of Votes']].groupby('Ratings').sum()
rating_votes=rating_votes.reset_index()
rating_votes
# Out:
#     Ratings  No of Votes
# 0       2.1        882.0
# 1       2.2        961.0
# 2       2.3        409.0
# 3       2.4       1515.0
# 4       2.5       2426.0
# 5       2.6       2120.0
# 6       2.7       3159.0
# 7       2.8       5949.0
# 8       2.9       7622.0
# 9       3.0       7914.0
# 10      3.1       7708.0
# 11      3.2      10039.0
# 12      3.3      16593.0
# 13      3.4      20874.0
# 14      3.5      26280.0
# 15      3.6      35097.0
# 16      3.7      46461.0
# 17      3.8      55788.0
# 18      3.9      61782.0
# 19      4.0      69467.0
# 20      4.1      73929.0
# 21      4.2      55685.0
# 22      4.3      48200.0
# 23      4.4      47701.0
# 24      4.5      24192.0
# 25      4.6      25488.0
# 26      4.7      25065.0
# 27      4.8      25167.0
# 28      4.9      10767.0

# %%
sns.relplot(x='Ratings',y='No of Votes',data=rating_votes,kind='line')

# %%
# sometimes some areas has high class restaurants so they have high ratings. so we can relate Location and ratings.
# based on this we can see which location restaurant got high ratings
f,ax=plt.subplots(figsize=(10,50))
plt.barh(width=data['Ratings'],y=data['Location'])
plt.xticks(rotation=90)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.]), <a list of 7 Text xticklabel objects>)

# %%
# price rate of food also based on the location. so we can relate location and rate
#from this we can see which restaurant is most expensive
plt.subplots(figsize=(10,50))
plt.barh(width=data['Price for 2'],y=data['Location'])
# from this we can see mahabalipuram resort and Guindy grand chola restaurant is most expensive
# Out:
# <BarContainer object of 8505 artists>
